# %%
import pandas as pd
import numpy as np
# %run Spotify_Script.ipynb

# %%
dataset = pd.read_csv("rockpopdataset.csv")
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# dataset = dataset.drop(columns = ["Unnamed: 0"])
dataset
# Out:
#        Unnamed: 0                            song        year  \
# 0               0                       ego remix  2009-01-01
# 1               1                    then tell me  2009-01-01
# 2               2                         honesty  2009-01-01
# 3               3                 you are my rock  2009-01-01
# 4               4                   black culture  2009-01-01
# ...           ...                             ...         ...
# 125539     198485  photographs you are taking now  2014-01-01
# 125540     198486                      you and me  2014-01-01
# 125541     198487                    hollow ponds  2014-01-01
# 125542     198488               the selfish giant  2014-01-01
# 125543     198489                        hostiles  2014-01-01
#
#                  artist genre  \
# 0       beyonce knowles   Pop
# 1       beyonce knowles   Pop
# 2       beyonce knowles   Pop
# 3       beyonce knowles   Pop
# 4       beyonce knowles   Pop
# ...                 ...   ...
# 125539     damon albarn   Pop
# 125540     damon albarn   Pop
# 125541     damon albarn   Pop
# 125542     damon albarn   Pop
# 125543     damon albarn   Pop
#
#                                                    lyrics  \
# 0       Oh baby, how you doing? You know I'm gonna cut...
# 1       playin' everything so easy, it's like you seem...
# 2       If you search For tenderness It isn't hard to ...
# 3       Oh oh oh I, oh oh oh I [Verse 1:] If I wrote a...
# 4       Party the people, the people the party it's po...
# ...                                                   ...
# 125539  When the photographs you're taking now Are tak...
# 125540  I met Moko jumbie, He walks on stilts through ...
# 125541  Chill on the hollow ponds Set sail by a kid In...
# 125542  Celebrate the passing drugs Put them on the ba...
# 125543  When the serve is done And the parish shuffled...
#
#                                           filtered_lyrics  misspelled_words  \
# 0       oh baby know im gonna cut right chase women ma...               0.0
# 1       playin everything easy like seem sure still wa...               0.0
# 2       search tenderness isnt hard find love need liv...               0.0
# 3       oh oh oh oh oh oh verse  wrote book stand titl...               0.0
# 4       party people people party popping sitting arou...               1.0
# ...                                                   ...               ...
# 125539  photographs youre taking taken heavy clouds hi...               1.0
# 125540  met moko jumbie walks stilts saints row lookin...               4.0
# 125541  chill hollow ponds set sail kid heat wave hit ...               0.0
# 125542  celebrate passing drugs put back seat theyre c...               1.0
# 125543  serve done parish shuffled may frequencies com...               2.0
#
#         unique_words  slang_words
# 0               95.0          3.0
# 1               78.0          5.0
# 2               63.0          2.0
# 3               83.0          4.0
# 4               27.0          1.0
# ...              ...          ...
# 125539          59.0          0.0
# 125540          66.0          0.0
# 125541          36.0          0.0
# 125542          45.0          0.0
# 125543          47.0          2.0
#
# [125544 rows x 10 columns]

# %%
audio_features = pd.read_csv("audiofeatures")

# %%
# audio_features = pd.DataFrame(columns = ["title", "artist", "genre", "features"])
count = 0
for idx, row in dataset.iterrows():
    count = count + 1
    if row["song"] not in audio_features["title"] and row["artist"] not in audio_features["artist"]:
        title = row["song"]
        artist = row["artist"]
        try:
            features = getFeatures(title, artist)
        except: 
            continue
        if features == None:
            continue
        audio_features = audio_features.append({'title': row.song, 'artist': row.artist, "genre": row.genre, 'features': features}, ignore_index=True)

# %%
audio_features

# %%
audio_features.where(audio_features["features"] == None)

# %%
audio_features.to_csv("audiofeatures")
